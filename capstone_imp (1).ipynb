# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/train.csv")
df.head()
# Out:
#                                             document  \
# 0  jason blake of the islanders will miss the res...
# 1  the u.s. military on wednesday captured a wife...
# 2  craig bellamy 's future at west ham appeared i...
# 3  cambridge - when barack obama sought advice be...
# 4  wall street held on to steep gains on monday ,...
#
#                                              summary
# 0                       blake missing rest of season
# 1  u.s. arrests wife and daughter of saddam deput...
# 2       west ham drops bellamy amid transfer turmoil
# 3        in search for expertise harvard looms large
# 4         wall street ends a three-day losing streak

# %%
frac_to_keep = 0.5
df = df.sample(frac=frac_to_keep)

# Reset the index if needed
df.reset_index(drop=True, inplace=True)

# Display the resulting DataFrame
dataset= df

# %%
dataset=df.rename(columns={'document':'text'})
dataset.head()
# Out:
#                                                 text  \
# 0  results of play saturday in the davis cup euro...
# 1  a powerful new earthquake rumbled across the r...
# 2  a half-century since his death , german scient...
# 3  mexicans were thursday counting the human and ...
# 4  cypriot president tassos papadopoulos and un s...
#
#                                              summary
# 0                              egypt # ivory coast #
# 1                  new quake triggers panic in haiti
# 2  after all these years einstein still austria '...
# 3  mexicans count cost of flu urged to spend holi...
# 4              cypriot president un chief hold talks

# %%
dataset.shape
# Out:
# (10000, 2)

# %%
dataset.isnull().sum()
# Out:
# text       0
# summary    0
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['text', 'summary'], dtype='object')

# %%
from sklearn.model_selection import train_test_split
X = dataset['text']
y = dataset['summary']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20,random_state = 42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (8000,) (2000,) (8000,) (2000,)

# %%
train_df = pd.concat([X_train,y_train],axis=1, ignore_index=True)
test_df = pd.concat([X_test, y_test],axis=1, ignore_index=True)

# %%
train_df= train_df.rename(columns={0:'text',1:'summary'})
test_df= test_df.rename(columns={0:'text',1:'summary'})

# %%
import torch

# %%
if torch.cuda.is_available():
    dev = torch.device("cuda:0")
    print("Running on the GPU")
else:
    dev = torch.device("cpu")
    print("Running on the CPU")
# Out:
# Running on the GPU

# %%
from IPython.display import HTML, display
def progress(loss,value, max=100):
 return HTML(""" Batch loss :{loss}
      <progress
value='{value}'max='{max}',style='width: 100%'>{value}
      </progress>
             """.format(loss=loss,value=value, max=max))

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.34.1-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 72.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 42.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 81.2 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 33.9 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.34.1

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("JulesBelveze/t5-small-headline-generator")
model = AutoModelForSeq2SeqLM.from_pretrained("JulesBelveze/t5-small-headline-generator")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.36k [00:00<?, ?B/s]
# Downloading spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]

# %%
model.to(dev)
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32100, 512)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32100, 512)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=512, bias=False)
#               (k): Linear(in_features=512, out_features=512, bias=False)
#               (v): Linear(in_features=512, out_features=512, bias=False)
#               (o): Linear(in_features=512, out_features=512, bias=False)
#               (relative_attention_bias): Embedding(32, 8)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=512, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-5): 5 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=512, bias=False)
#               (k): Linear(in_features=512, out_features=512, bias=False)
#               (v): Linear(in_features=512, out_features=512, bias=False)
#               (o): Linear(in_features=512, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=512, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32100, 512)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=512, bias=False)
#               (k): Linear(in_features=512, out_features=512, bias=False)
#               (v): Linear(in_features=512, out_features=512, bias=False)
#               (o): Linear(in_features=512, out_features=512, bias=False)
#               (relative_attention_bias): Embedding(32, 8)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=512, bias=False)
#               (k): Linear(in_features=512, out_features=512, bias=False)
#               (v): Linear(in_features=512, out_features=512, bias=False)
#               (o): Linear(in_features=512, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=512, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-5): 5 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=512, bias=False)
#               (k): Linear(in_features=512, out_features=512, bias=False)
#               (v): Linear(in_features=512, out_features=512, bias=False)
#               (o): Linear(in_features=512, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=512, out_features=512, bias=False)
#               (k): Linear(in_features=512, out_features=512, bias=False)
#               (v): Linear(in_features=512, out_features=512, bias=False)
#               (o): Linear(in_features=512, out_features=512, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseActDense(
#               (wi): Linear(in_features=512, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=512, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): ReLU()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=512, out_features=32100, bias=False)
# )

# %%
batch_size=6
num_of_batches=int(len(X_train)/batch_size)

# %%
from transformers import Adafactor
optimizer = Adafactor(model.parameters(),lr=1e-4,
                      eps=(1e-30, 1e-3),
                      clip_threshold=1.0,
                      decay_rate=-0.8,
                      beta1=None,
                      weight_decay=1e-4,
                      relative_step=False,
                      scale_parameter=False,
                      warmup_init=False)

# %%
def trainfun(model, train_df, batch_size, num_of_epochs, optimizer):
    model.train()
    num_of_batches = int(len(train_df) / batch_size)
    loss_per_10_steps = []
    for epoch in range(1, num_of_epochs + 1):
        print('Running epoch: {}'.format(epoch))
        running_loss = 0
        out = display(progress(1, num_of_batches + 1), display_id=True)
        for i in range(num_of_batches):
            inputbatch = []
            labelbatch = []
            new_df = train_df[i * batch_size:i * batch_size + batch_size]
            for indx, row in new_df.iterrows():
                input = str(row['text']) + '[SEP]'
                labels = row['summary'] + '[SEP]'
                inputbatch.append(input)
                labelbatch.append(labels)
            inputbatch = tokenizer.batch_encode_plus(inputbatch, padding=True, max_length=512, return_tensors='pt')["input_ids"]
            labelbatch = tokenizer.batch_encode_plus(labelbatch, padding=True, max_length=512, return_tensors="pt")["input_ids"]
            inputbatch = inputbatch.to(dev)
            labelbatch = labelbatch.to(dev)

            optimizer.zero_grad()

            # Forward propagation
            outputs = model(input_ids=inputbatch, labels=labelbatch)
            loss = outputs.loss
            loss_num = loss.item()
            logits = outputs.logits
            running_loss += loss_num
            if i % 10 == 0:
                loss_per_10_steps.append(loss_num)
                out.update(progress(loss_num, i, num_of_batches + 1))

            # Calculating the gradients
            loss.backward()

            # Updating the parameters
            optimizer.step()

        running_loss = running_loss / int(num_of_batches)
        print('Epoch: {} , Running loss: {}'.format(epoch, running_loss))

    return model, loss_per_10_steps

model, loss_per_10_steps = trainfun(model, train_df, batch_size, 25, optimizer)
# Out:
# Running epoch: 1
#  Batch loss :1.8373583555221558
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2624: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# Epoch: 1 , Running loss: 1.5657816818577852
# Running epoch: 2
#  Batch loss :1.7311468124389648
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 2 , Running loss: 1.3533791586678456
# Running epoch: 3
#  Batch loss :1.6646960973739624
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 3 , Running loss: 1.2688474906000622
# Running epoch: 4
#  Batch loss :1.6380857229232788
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 4 , Running loss: 1.2024275622283795
# Running epoch: 5
#  Batch loss :1.496741533279419
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 5 , Running loss: 1.144940816832948
# Running epoch: 6
#  Batch loss :1.5127047300338745
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 6 , Running loss: 1.0945641245282152
# Running epoch: 7
#  Batch loss :1.3770431280136108
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 7 , Running loss: 1.0492497277903718
# Running epoch: 8
#  Batch loss :1.345244288444519
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 8 , Running loss: 1.007838261436003
# Running epoch: 9
#  Batch loss :1.3979781866073608
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 9 , Running loss: 0.9739394067644804
# Running epoch: 10
#  Batch loss :1.2561407089233398
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 10 , Running loss: 0.9358672804610674
# Running epoch: 11
#  Batch loss :1.2691521644592285
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 11 , Running loss: 0.9027031239091411
# Running epoch: 12
#  Batch loss :1.2475323677062988
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 12 , Running loss: 0.8717002654916258
# Running epoch: 13
#  Batch loss :1.203652262687683
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 13 , Running loss: 0.84186148498171
# Running epoch: 14
#  Batch loss :1.2227065563201904
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 14 , Running loss: 0.8113328811041144
# Running epoch: 15
#  Batch loss :1.1538114547729492
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 15 , Running loss: 0.7889066682842023
# Running epoch: 16
#  Batch loss :1.2243614196777344
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 16 , Running loss: 0.7609872673676592
# Running epoch: 17
#  Batch loss :1.049626111984253
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 17 , Running loss: 0.7371773918097124
# Running epoch: 18
#  Batch loss :1.1300565004348755
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 18 , Running loss: 0.714470989862422
# Running epoch: 19
#  Batch loss :1.1379077434539795
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 19 , Running loss: 0.6930472840962335
# Running epoch: 20
#  Batch loss :1.1008602380752563
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 20 , Running loss: 0.6705029907637043
# Running epoch: 21
#  Batch loss :0.9173896312713623
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 21 , Running loss: 0.6518972986234549
# Running epoch: 22
#  Batch loss :0.9820463061332703
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 22 , Running loss: 0.6319795198017552
# Running epoch: 23
#  Batch loss :0.9455524682998657
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 23 , Running loss: 0.6106595177558339
# Running epoch: 24
#  Batch loss :1.0457994937896729
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 24 , Running loss: 0.5924890738341116
# Running epoch: 25
#  Batch loss :0.9033384323120117
#       <progress
# value='1330'max='1334',style='width: 100%'>1330
#       </progress>
# Epoch: 25 , Running loss: 0.5731598515921487

# %%
import matplotlib.pyplot as plt

plt.plot(range(1, len(loss_per_10_steps) + 1), loss_per_10_steps, marker='o', linestyle='-')
plt.xlabel('Batches')
plt.ylabel('Batch Loss')
plt.title('Batch Loss vs. Batches')
plt.grid()
plt.show()

# %%
torch.save(model.state_dict(), "t5_model.pt")

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch

# Loading the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("JulesBelveze/t5-small-headline-generator")
model = AutoModelForSeq2SeqLM.from_pretrained("JulesBelveze/t5-small-headline-generator")

# model.load_state_dict(torch.load("t5_model.pt"))
model.to(dev)
model.eval()

# Defining a function to generate summaries
def generate_summary(texts):
    summaries = []
    for text in texts:
        input_text = text + '[SEP]'
        input_ids = tokenizer.encode(input_text, return_tensors="pt", max_length=512, padding=True).to(dev)
        output_ids = model.generate(input_ids, num_beams=8, do_sample=True, min_length=10, max_length=512)
        summary = tokenizer.decode(output_ids[0], skip_special_tokens=True)
        summaries.append(summary)
    return summaries

# Generating summaries for test_df['text']
test_texts = test_df['text'].tolist()
generated_summaries = generate_summary(test_texts)

# Printing the first generated summary as an example
print("Original Text:\n", test_texts[0], "\n")
print("Generated Summary:\n", generated_summaries[0])
# Out:
# Original Text:
#  steve <unk> and mamadou diallo scored late goals as the tampa bay mutiny beat the undermanned los angeles galaxy #-# on saturday night .
#
# Generated Summary:
#  [SEP] Tampa bay mutiny beat the undermanned los angeles galaxy #-# on saturday night

# %%
pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.34.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.16.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (3.8.1)
# Collecting sentencepiece (from sentence-transformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.9 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.17.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.12.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=926375be241511801e586e8fa61c8807ae36c935bbe7561451bda60067ea5796
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: sentencepiece, sentence-transformers
# Successfully installed sentence-transformers-2.2.2 sentencepiece-0.1.99

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import numpy as np

# %%
model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')
# Out:
# Downloading (…)a8e1d/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)b20bca8e1d/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)0bca8e1d/config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)e1d/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading (…)a8e1d/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading (…)8e1d/train_script.py:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading (…)b20bca8e1d/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)bca8e1d/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
test_df_review_summary = test_df["summary"].tolist()
test_df_predicted = generated_summaries

# %%
similarity_scores = []
for rs_text, p_text in zip(test_df_review_summary, test_df_predicted):
    rs_embedding = model.encode(rs_text)
    p_embedding = model.encode(p_text)
    similarity = np.inner(rs_embedding, p_embedding)
    similarity_scores.append(similarity)

# %%
# Printing the similarity scores for each pair
for i, similarity_score in enumerate(similarity_scores):
    print(f"Similarity between 'summary {i+1}' and its 'predicted': {similarity_score:.4f}")
# Out:
# Similarity between 'summary 1' and its 'predicted': 0.5207
# Similarity between 'summary 2' and its 'predicted': 0.5119
# Similarity between 'summary 3' and its 'predicted': 0.4869
# Similarity between 'summary 4' and its 'predicted': 0.8784
# Similarity between 'summary 5' and its 'predicted': 0.8145
# Similarity between 'summary 6' and its 'predicted': 0.5730
# Similarity between 'summary 7' and its 'predicted': 0.7468
# Similarity between 'summary 8' and its 'predicted': 0.8706
# Similarity between 'summary 9' and its 'predicted': 0.8201
# Similarity between 'summary 10' and its 'predicted': 0.6896
# Similarity between 'summary 11' and its 'predicted': 0.7716
# Similarity between 'summary 12' and its 'predicted': 0.8228
# Similarity between 'summary 13' and its 'predicted': 0.8670
# Similarity between 'summary 14' and its 'predicted': 0.2475
# Similarity between 'summary 15' and its 'predicted': 0.5077
# Similarity between 'summary 16' and its 'predicted': 0.7162
# Similarity between 'summary 17' and its 'predicted': 0.7330
# Similarity between 'summary 18' and its 'predicted': 0.8519
# Similarity between 'summary 19' and its 'predicted': 0.5680
# Similarity between 'summary 20' and its 'predicted': 0.0172
# Similarity between 'summary 21' and its 'predicted': 0.7779
# Similarity between 'summary 22' and its 'predicted': 0.8542
# Similarity between 'summary 23' and its 'predicted': 0.7603
# Similarity between 'summary 24' and its 'predicted': 0.6459
# Similarity between 'summary 25' and its 'predicted': 0.3971
# Similarity between 'summary 26' and its 'predicted': 0.7066
# Similarity between 'summary 27' and its 'predicted': 0.5004
# Similarity between 'summary 28' and its 'predicted': 0.7140
# Similarity between 'summary 29' and its 'predicted': 0.4867
# Similarity between 'summary 30' and its 'predicted': 0.4860
# Similarity between 'summary 31' and its 'predicted': 0.3238
# Similarity between 'summary 32' and its 'predicted': 0.8112
# Similarity between 'summary 33' and its 'predicted': 0.7767
# Similarity between 'summary 34' and its 'predicted': 0.9315
# Similarity between 'summary 35' and its 'predicted': 0.7265
# Similarity between 'summary 36' and its 'predicted': 0.6957
# Similarity between 'summary 37' and its 'predicted': 0.6191
# Similarity between 'summary 38' and its 'predicted': 0.8239
# Similarity between 'summary 39' and its 'predicted': 0.5475
# Similarity between 'summary 40' and its 'predicted': 0.7812
# Similarity between 'summary 41' and its 'predicted': 0.7751
# Similarity between 'summary 42' and its 'predicted': 0.7816
# Similarity between 'summary 43' and its 'predicted': 0.6052
# Similarity between 'summary 44' and its 'predicted': 0.8854
# Similarity between 'summary 45' and its 'predicted': 0.5406
# Similarity between 'summary 46' and its 'predicted': 0.9164
# Similarity between 'summary 47' and its 'predicted': 0.6476
# Similarity between 'summary 48' and its 'predicted': 0.7008
# Similarity between 'summary 49' and its 'predicted': 0.6400
# Similarity between 'summary 50' and its 'predicted': 0.4646
# Similarity between 'summary 51' and its 'predicted': 0.8950
# Similarity between 'summary 52' and its 'predicted': 0.6421
# Similarity between 'summary 53' and its 'predicted': 0.6186
# Similarity between 'summary 54' and its 'predicted': 0.8659
# Similarity between 'summary 55' and its 'predicted': 0.7963
# Similarity between 'summary 56' and its 'predicted': 0.5180
# Similarity between 'summary 57' and its 'predicted': 0.6417
# Similarity between 'summary 58' and its 'predicted': 0.4950
# Similarity between 'summary 59' and its 'predicted': 0.6281
# Similarity between 'summary 60' and its 'predicted': 0.5533
# Similarity between 'summary 61' and its 'predicted': 0.7226
# Similarity between 'summary 62' and its 'predicted': 0.1938
# Similarity between 'summary 63' and its 'predicted': 0.6485
# Similarity between 'summary 64' and its 'predicted': 0.9082
# Similarity between 'summary 65' and its 'predicted': 0.6162
# Similarity between 'summary 66' and its 'predicted': 0.8457
# Similarity between 'summary 67' and its 'predicted': 0.7781
# Similarity between 'summary 68' and its 'predicted': 0.8094
# Similarity between 'summary 69' and its 'predicted': 0.8636
# Similarity between 'summary 70' and its 'predicted': 0.3937
# Similarity between 'summary 71' and its 'predicted': 0.6651
# Similarity between 'summary 72' and its 'predicted': 0.7958
# Similarity between 'summary 73' and its 'predicted': 0.5707
# Similarity between 'summary 74' and its 'predicted': 0.6233
# Similarity between 'summary 75' and its 'predicted': 0.3335
# Similarity between 'summary 76' and its 'predicted': 0.7423
# Similarity between 'summary 77' and its 'predicted': -0.0077
# Similarity between 'summary 78' and its 'predicted': 0.7229
# Similarity between 'summary 79' and its 'predicted': 0.7607
# Similarity between 'summary 80' and its 'predicted': 0.7609
# Similarity between 'summary 81' and its 'predicted': 0.8402
# Similarity between 'summary 82' and its 'predicted': 0.8021
# Similarity between 'summary 83' and its 'predicted': 0.5699
# Similarity between 'summary 84' and its 'predicted': 0.4707
# Similarity between 'summary 85' and its 'predicted': 0.6790
# Similarity between 'summary 86' and its 'predicted': 0.6400
# Similarity between 'summary 87' and its 'predicted': 0.9088
# Similarity between 'summary 88' and its 'predicted': 0.3670
# Similarity between 'summary 89' and its 'predicted': 0.7484
# Similarity between 'summary 90' and its 'predicted': 0.8108
# Similarity between 'summary 91' and its 'predicted': 0.8554
# Similarity between 'summary 92' and its 'predicted': 0.8633
# Similarity between 'summary 93' and its 'predicted': 0.6163
# Similarity between 'summary 94' and its 'predicted': 0.7169
# Similarity between 'summary 95' and its 'predicted': 0.5475
# Similarity between 'summary 96' and its 'predicted': 0.8262
# Similarity between 'summary 97' and its 'predicted': 0.6593
# Similarity between 'summary 98' and its 'predicted': 0.5022
# Similarity between 'summary 99' and its 'predicted': 0.7926
# Similarity between 'summary 100' and its 'predicted': 0.5129
# Similarity between 'summary 101' and its 'predicted': 0.1207
# Similarity between 'summary 102' and its 'predicted': 0.3487
# Similarity between 'summary 103' and its 'predicted': 0.6146
# Similarity between 'summary 104' and its 'predicted': 0.8180
# Similarity between 'summary 105' and its 'predicted': 0.3477
# Similarity between 'summary 106' and its 'predicted': 0.6327
# Similarity between 'summary 107' and its 'predicted': 0.5226
# Similarity between 'summary 108' and its 'predicted': 0.6000
# Similarity between 'summary 109' and its 'predicted': 0.6248
# Similarity between 'summary 110' and its 'predicted': 0.8402
# Similarity between 'summary 111' and its 'predicted': 0.6997
# Similarity between 'summary 112' and its 'predicted': 0.7435
# Similarity between 'summary 113' and its 'predicted': 0.7150
# Similarity between 'summary 114' and its 'predicted': 0.8282
# Similarity between 'summary 115' and its 'predicted': 0.7011
# Similarity between 'summary 116' and its 'predicted': 0.5120
# Similarity between 'summary 117' and its 'predicted': 0.8052
# Similarity between 'summary 118' and its 'predicted': 0.8780
# Similarity between 'summary 119' and its 'predicted': 0.7181
# Similarity between 'summary 120' and its 'predicted': 0.7955
# Similarity between 'summary 121' and its 'predicted': 0.3708
# Similarity between 'summary 122' and its 'predicted': 0.5388
# Similarity between 'summary 123' and its 'predicted': 0.7455
# Similarity between 'summary 124' and its 'predicted': 0.7322
# Similarity between 'summary 125' and its 'predicted': 0.7597
# Similarity between 'summary 126' and its 'predicted': 0.3686
# Similarity between 'summary 127' and its 'predicted': 0.8987
# Similarity between 'summary 128' and its 'predicted': 0.1440
# Similarity between 'summary 129' and its 'predicted': 0.8399
# Similarity between 'summary 130' and its 'predicted': 0.7400
# Similarity between 'summary 131' and its 'predicted': 0.8690
# Similarity between 'summary 132' and its 'predicted': 0.5566
# Similarity between 'summary 133' and its 'predicted': 0.7229
# Similarity between 'summary 134' and its 'predicted': 0.7267
# Similarity between 'summary 135' and its 'predicted': 0.4138
# Similarity between 'summary 136' and its 'predicted': 0.6306
# Similarity between 'summary 137' and its 'predicted': 0.5169
# Similarity between 'summary 138' and its 'predicted': 0.5662
# Similarity between 'summary 139' and its 'predicted': 0.6128
# Similarity between 'summary 140' and its 'predicted': 0.8443
# Similarity between 'summary 141' and its 'predicted': 0.8431
# Similarity between 'summary 142' and its 'predicted': 0.7280
# Similarity between 'summary 143' and its 'predicted': 0.6499
# Similarity between 'summary 144' and its 'predicted': 0.7421
# Similarity between 'summary 145' and its 'predicted': 0.2577
# Similarity between 'summary 146' and its 'predicted': 0.7543
# Similarity between 'summary 147' and its 'predicted': 0.6811
# Similarity between 'summary 148' and its 'predicted': 0.9444
# Similarity between 'summary 149' and its 'predicted': 0.7930
# Similarity between 'summary 150' and its 'predicted': 0.7782
# Similarity between 'summary 151' and its 'predicted': 0.7849
# Similarity between 'summary 152' and its 'predicted': 0.8255
# Similarity between 'summary 153' and its 'predicted': 0.8004
# Similarity between 'summary 154' and its 'predicted': 0.5490
# Similarity between 'summary 155' and its 'predicted': 0.6621
# Similarity between 'summary 156' and its 'predicted': 0.1322
# Similarity between 'summary 157' and its 'predicted': 0.5554
# Similarity between 'summary 158' and its 'predicted': 0.4194
# Similarity between 'summary 159' and its 'predicted': 0.5204
# Similarity between 'summary 160' and its 'predicted': 0.6823
# Similarity between 'summary 161' and its 'predicted': 0.8187
# Similarity between 'summary 162' and its 'predicted': 0.1021
# Similarity between 'summary 163' and its 'predicted': 0.8339
# Similarity between 'summary 164' and its 'predicted': 0.0750
# Similarity between 'summary 165' and its 'predicted': 0.6378
# Similarity between 'summary 166' and its 'predicted': 0.7750
# Similarity between 'summary 167' and its 'predicted': 0.7359
# Similarity between 'summary 168' and its 'predicted': 0.5915
# Similarity between 'summary 169' and its 'predicted': 0.6970
# Similarity between 'summary 170' and its 'predicted': 0.5089
# Similarity between 'summary 171' and its 'predicted': 0.8252
# Similarity between 'summary 172' and its 'predicted': 0.8304
# Similarity between 'summary 173' and its 'predicted': 0.5198
# Similarity between 'summary 174' and its 'predicted': 0.3748
# Similarity between 'summary 175' and its 'predicted': 0.8570
# Similarity between 'summary 176' and its 'predicted': 0.7112
# Similarity between 'summary 177' and its 'predicted': 0.5575
# Similarity between 'summary 178' and its 'predicted': 0.5497
# Similarity between 'summary 179' and its 'predicted': 0.8360
# Similarity between 'summary 180' and its 'predicted': 0.6746
# Similarity between 'summary 181' and its 'predicted': 0.7474
# Similarity between 'summary 182' and its 'predicted': 0.6354
# Similarity between 'summary 183' and its 'predicted': 0.8501
# Similarity between 'summary 184' and its 'predicted': 0.7119
# Similarity between 'summary 185' and its 'predicted': 0.5972
# Similarity between 'summary 186' and its 'predicted': 0.6912
# Similarity between 'summary 187' and its 'predicted': 0.8382
# Similarity between 'summary 188' and its 'predicted': 0.0257
# Similarity between 'summary 189' and its 'predicted': 0.4989
# Similarity between 'summary 190' and its 'predicted': 0.6239
# Similarity between 'summary 191' and its 'predicted': 0.7262
# Similarity between 'summary 192' and its 'predicted': 0.7728
# Similarity between 'summary 193' and its 'predicted': 0.8110
# Similarity between 'summary 194' and its 'predicted': 0.5118
# Similarity between 'summary 195' and its 'predicted': 0.8415
# Similarity between 'summary 196' and its 'predicted': 0.7333
# Similarity between 'summary 197' and its 'predicted': 0.5930
# Similarity between 'summary 198' and its 'predicted': 0.5041
# Similarity between 'summary 199' and its 'predicted': 0.9538
# Similarity between 'summary 200' and its 'predicted': 0.8251
# Similarity between 'summary 201' and its 'predicted': 0.4716
# Similarity between 'summary 202' and its 'predicted': 0.7897
# Similarity between 'summary 203' and its 'predicted': 0.5153
# Similarity between 'summary 204' and its 'predicted': 0.8749
# Similarity between 'summary 205' and its 'predicted': 0.3631
# Similarity between 'summary 206' and its 'predicted': 0.7740
# Similarity between 'summary 207' and its 'predicted': 0.0047
# Similarity between 'summary 208' and its 'predicted': 0.7741
# Similarity between 'summary 209' and its 'predicted': 0.7344
# Similarity between 'summary 210' and its 'predicted': 0.0323
# Similarity between 'summary 211' and its 'predicted': 0.7074
# Similarity between 'summary 212' and its 'predicted': 0.7905
# Similarity between 'summary 213' and its 'predicted': 0.7328
# Similarity between 'summary 214' and its 'predicted': 0.5127
# Similarity between 'summary 215' and its 'predicted': 0.6388
# Similarity between 'summary 216' and its 'predicted': 0.3855
# Similarity between 'summary 217' and its 'predicted': 0.8225
# Similarity between 'summary 218' and its 'predicted': 0.8061
# Similarity between 'summary 219' and its 'predicted': 0.6894
# Similarity between 'summary 220' and its 'predicted': 0.8047
# Similarity between 'summary 221' and its 'predicted': 0.4849
# Similarity between 'summary 222' and its 'predicted': 0.4776
# Similarity between 'summary 223' and its 'predicted': 0.7011
# Similarity between 'summary 224' and its 'predicted': 0.7397
# Similarity between 'summary 225' and its 'predicted': 0.3331
# Similarity between 'summary 226' and its 'predicted': 0.6130
# Similarity between 'summary 227' and its 'predicted': 0.7363
# Similarity between 'summary 228' and its 'predicted': 0.3665
# Similarity between 'summary 229' and its 'predicted': 0.8492
# Similarity between 'summary 230' and its 'predicted': 0.6679
# Similarity between 'summary 231' and its 'predicted': 0.4043
# Similarity between 'summary 232' and its 'predicted': 0.9148
# Similarity between 'summary 233' and its 'predicted': 0.7720
# Similarity between 'summary 234' and its 'predicted': 0.6202
# Similarity between 'summary 235' and its 'predicted': 0.1667
# Similarity between 'summary 236' and its 'predicted': 0.7148
# Similarity between 'summary 237' and its 'predicted': 0.5378
# Similarity between 'summary 238' and its 'predicted': 0.7257
# Similarity between 'summary 239' and its 'predicted': 0.7738
# Similarity between 'summary 240' and its 'predicted': 0.8050
# Similarity between 'summary 241' and its 'predicted': 0.6193
# Similarity between 'summary 242' and its 'predicted': 0.7215
# Similarity between 'summary 243' and its 'predicted': 0.0824
# Similarity between 'summary 244' and its 'predicted': 0.8284
# Similarity between 'summary 245' and its 'predicted': 0.7354
# Similarity between 'summary 246' and its 'predicted': 0.6717
# Similarity between 'summary 247' and its 'predicted': 0.7358
# Similarity between 'summary 248' and its 'predicted': 0.0600
# Similarity between 'summary 249' and its 'predicted': 0.8028
# Similarity between 'summary 250' and its 'predicted': 0.4313
# Similarity between 'summary 251' and its 'predicted': 0.5048
# Similarity between 'summary 252' and its 'predicted': 0.8650
# Similarity between 'summary 253' and its 'predicted': 0.6519
# Similarity between 'summary 254' and its 'predicted': 0.7276
# Similarity between 'summary 255' and its 'predicted': 0.6737
# Similarity between 'summary 256' and its 'predicted': 0.6913
# Similarity between 'summary 257' and its 'predicted': 0.7922
# Similarity between 'summary 258' and its 'predicted': 0.6468
# Similarity between 'summary 259' and its 'predicted': 0.4163
# Similarity between 'summary 260' and its 'predicted': 0.6632
# Similarity between 'summary 261' and its 'predicted': 0.6908
# Similarity between 'summary 262' and its 'predicted': 0.7556
# Similarity between 'summary 263' and its 'predicted': 0.7830
# Similarity between 'summary 264' and its 'predicted': 0.6384
# Similarity between 'summary 265' and its 'predicted': 0.5105
# Similarity between 'summary 266' and its 'predicted': 0.7920
# Similarity between 'summary 267' and its 'predicted': 0.3988
# Similarity between 'summary 268' and its 'predicted': 0.6242
# Similarity between 'summary 269' and its 'predicted': 0.8035
# Similarity between 'summary 270' and its 'predicted': 0.6283
# Similarity between 'summary 271' and its 'predicted': 0.5934
# Similarity between 'summary 272' and its 'predicted': 0.4912
# Similarity between 'summary 273' and its 'predicted': 0.7578
# Similarity between 'summary 274' and its 'predicted': 0.7574
# Similarity between 'summary 275' and its 'predicted': 0.2244
# Similarity between 'summary 276' and its 'predicted': 0.3997
# Similarity between 'summary 277' and its 'predicted': 0.4618
# Similarity between 'summary 278' and its 'predicted': 0.6715
# Similarity between 'summary 279' and its 'predicted': 0.7798
# Similarity between 'summary 280' and its 'predicted': 0.7427
# Similarity between 'summary 281' and its 'predicted': 0.6926
# Similarity between 'summary 282' and its 'predicted': 0.5267
# Similarity between 'summary 283' and its 'predicted': 0.7516
# Similarity between 'summary 284' and its 'predicted': 0.7913
# Similarity between 'summary 285' and its 'predicted': 0.5062
# Similarity between 'summary 286' and its 'predicted': 0.8181
# Similarity between 'summary 287' and its 'predicted': 0.8364
# Similarity between 'summary 288' and its 'predicted': 0.6615
# Similarity between 'summary 289' and its 'predicted': 0.5515
# Similarity between 'summary 290' and its 'predicted': 0.7921
# Similarity between 'summary 291' and its 'predicted': 0.7235
# Similarity between 'summary 292' and its 'predicted': 0.8765
# Similarity between 'summary 293' and its 'predicted': 0.4792
# Similarity between 'summary 294' and its 'predicted': 0.4574
# Similarity between 'summary 295' and its 'predicted': 0.4662
# Similarity between 'summary 296' and its 'predicted': 0.6658
# Similarity between 'summary 297' and its 'predicted': 0.5582
# Similarity between 'summary 298' and its 'predicted': 0.7067
# Similarity between 'summary 299' and its 'predicted': 0.8464
# Similarity between 'summary 300' and its 'predicted': 0.7879
# Similarity between 'summary 301' and its 'predicted': 0.7019
# Similarity between 'summary 302' and its 'predicted': 0.8472
# Similarity between 'summary 303' and its 'predicted': 0.7100
# Similarity between 'summary 304' and its 'predicted': 0.8689
# Similarity between 'summary 305' and its 'predicted': 0.6145
# Similarity between 'summary 306' and its 'predicted': 0.7062
# Similarity between 'summary 307' and its 'predicted': 0.8541
# Similarity between 'summary 308' and its 'predicted': 0.8456
# Similarity between 'summary 309' and its 'predicted': 0.4250
# Similarity between 'summary 310' and its 'predicted': 0.6909
# Similarity between 'summary 311' and its 'predicted': 0.7809
# Similarity between 'summary 312' and its 'predicted': 0.6476
# Similarity between 'summary 313' and its 'predicted': -0.0171
# Similarity between 'summary 314' and its 'predicted': 0.5723
# Similarity between 'summary 315' and its 'predicted': 0.7587
# Similarity between 'summary 316' and its 'predicted': 0.6325
# Similarity between 'summary 317' and its 'predicted': 0.4352
# Similarity between 'summary 318' and its 'predicted': 0.8117
# Similarity between 'summary 319' and its 'predicted': 0.9156
# Similarity between 'summary 320' and its 'predicted': 0.3907
# Similarity between 'summary 321' and its 'predicted': 0.5314
# Similarity between 'summary 322' and its 'predicted': 0.3606
# Similarity between 'summary 323' and its 'predicted': 0.6978
# Similarity between 'summary 324' and its 'predicted': 0.6382
# Similarity between 'summary 325' and its 'predicted': 0.4650
# Similarity between 'summary 326' and its 'predicted': 0.8012
# Similarity between 'summary 327' and its 'predicted': 0.6018
# Similarity between 'summary 328' and its 'predicted': 0.5476
# Similarity between 'summary 329' and its 'predicted': 0.8246
# Similarity between 'summary 330' and its 'predicted': 0.8804
# Similarity between 'summary 331' and its 'predicted': 0.8180
# Similarity between 'summary 332' and its 'predicted': 0.6057
# Similarity between 'summary 333' and its 'predicted': 0.8359
# Similarity between 'summary 334' and its 'predicted': 0.7331
# Similarity between 'summary 335' and its 'predicted': 0.6474
# Similarity between 'summary 336' and its 'predicted': 0.9053
# Similarity between 'summary 337' and its 'predicted': 0.7649
# Similarity between 'summary 338' and its 'predicted': 0.8996
# Similarity between 'summary 339' and its 'predicted': 0.6313
# Similarity between 'summary 340' and its 'predicted': 0.7900
# Similarity between 'summary 341' and its 'predicted': 0.7646
# Similarity between 'summary 342' and its 'predicted': 0.5488
# Similarity between 'summary 343' and its 'predicted': 0.8341
# Similarity between 'summary 344' and its 'predicted': 0.5846
# Similarity between 'summary 345' and its 'predicted': 0.7190
# Similarity between 'summary 346' and its 'predicted': 0.7110
# Similarity between 'summary 347' and its 'predicted': 0.8827
# Similarity between 'summary 348' and its 'predicted': 0.7899
# Similarity between 'summary 349' and its 'predicted': 0.8778
# Similarity between 'summary 350' and its 'predicted': 0.8596
# Similarity between 'summary 351' and its 'predicted': 0.5035
# Similarity between 'summary 352' and its 'predicted': 0.5149
# Similarity between 'summary 353' and its 'predicted': 0.6699
# Similarity between 'summary 354' and its 'predicted': 0.7399
# Similarity between 'summary 355' and its 'predicted': 0.7753
# Similarity between 'summary 356' and its 'predicted': 0.5892
# Similarity between 'summary 357' and its 'predicted': 0.6827
# Similarity between 'summary 358' and its 'predicted': 0.6553
# Similarity between 'summary 359' and its 'predicted': 0.7139
# Similarity between 'summary 360' and its 'predicted': 0.6879
# Similarity between 'summary 361' and its 'predicted': 0.8118
# Similarity between 'summary 362' and its 'predicted': 0.8031
# Similarity between 'summary 363' and its 'predicted': 0.7477
# Similarity between 'summary 364' and its 'predicted': 0.5414
# Similarity between 'summary 365' and its 'predicted': 0.5063
# Similarity between 'summary 366' and its 'predicted': 0.6397
# Similarity between 'summary 367' and its 'predicted': 0.7675
# Similarity between 'summary 368' and its 'predicted': 0.7293
# Similarity between 'summary 369' and its 'predicted': 0.7853
# Similarity between 'summary 370' and its 'predicted': 0.7299
# Similarity between 'summary 371' and its 'predicted': 0.7966
# Similarity between 'summary 372' and its 'predicted': 0.7115
# Similarity between 'summary 373' and its 'predicted': 0.5545
# Similarity between 'summary 374' and its 'predicted': 0.7548
# Similarity between 'summary 375' and its 'predicted': 0.7055
# Similarity between 'summary 376' and its 'predicted': 0.6993
# Similarity between 'summary 377' and its 'predicted': 0.7375
# Similarity between 'summary 378' and its 'predicted': 0.5510
# Similarity between 'summary 379' and its 'predicted': 0.6189
# Similarity between 'summary 380' and its 'predicted': 0.4829
# Similarity between 'summary 381' and its 'predicted': 0.7550
# Similarity between 'summary 382' and its 'predicted': 0.7706
# Similarity between 'summary 383' and its 'predicted': 0.7372
# Similarity between 'summary 384' and its 'predicted': 0.8577
# Similarity between 'summary 385' and its 'predicted': 0.8277
# Similarity between 'summary 386' and its 'predicted': 0.5694
# Similarity between 'summary 387' and its 'predicted': 0.8089
# Similarity between 'summary 388' and its 'predicted': 0.7418
# Similarity between 'summary 389' and its 'predicted': 0.7170
# Similarity between 'summary 390' and its 'predicted': 0.8853
# Similarity between 'summary 391' and its 'predicted': 0.7565
# Similarity between 'summary 392' and its 'predicted': 0.5562
# Similarity between 'summary 393' and its 'predicted': -0.0107
# Similarity between 'summary 394' and its 'predicted': 0.8195
# Similarity between 'summary 395' and its 'predicted': 0.8070
# Similarity between 'summary 396' and its 'predicted': 0.7138
# Similarity between 'summary 397' and its 'predicted': 0.6170
# Similarity between 'summary 398' and its 'predicted': 0.6133
# Similarity between 'summary 399' and its 'predicted': 0.6845
# Similarity between 'summary 400' and its 'predicted': 0.8214
# Similarity between 'summary 401' and its 'predicted': 0.6596
# Similarity between 'summary 402' and its 'predicted': 0.4348
# Similarity between 'summary 403' and its 'predicted': 0.6360
# Similarity between 'summary 404' and its 'predicted': 0.5051
# Similarity between 'summary 405' and its 'predicted': 0.8120
# Similarity between 'summary 406' and its 'predicted': 0.6797
# Similarity between 'summary 407' and its 'predicted': 0.7534
# Similarity between 'summary 408' and its 'predicted': 0.6437
# Similarity between 'summary 409' and its 'predicted': 0.6461
# Similarity between 'summary 410' and its 'predicted': 0.8232
# Similarity between 'summary 411' and its 'predicted': 0.7371
# Similarity between 'summary 412' and its 'predicted': 0.7374
# Similarity between 'summary 413' and its 'predicted': 0.5573
# Similarity between 'summary 414' and its 'predicted': 0.8407
# Similarity between 'summary 415' and its 'predicted': 0.7323
# Similarity between 'summary 416' and its 'predicted': 0.7012
# Similarity between 'summary 417' and its 'predicted': 0.7514
# Similarity between 'summary 418' and its 'predicted': 0.7269
# Similarity between 'summary 419' and its 'predicted': 0.6137
# Similarity between 'summary 420' and its 'predicted': 0.8101
# Similarity between 'summary 421' and its 'predicted': 0.7652
# Similarity between 'summary 422' and its 'predicted': 0.4103
# Similarity between 'summary 423' and its 'predicted': 0.5476
# Similarity between 'summary 424' and its 'predicted': 0.8598
# Similarity between 'summary 425' and its 'predicted': 0.6270
# Similarity between 'summary 426' and its 'predicted': 0.6691
# Similarity between 'summary 427' and its 'predicted': 0.4690
# Similarity between 'summary 428' and its 'predicted': 0.8560
# Similarity between 'summary 429' and its 'predicted': 0.5454
# Similarity between 'summary 430' and its 'predicted': 0.7945
# Similarity between 'summary 431' and its 'predicted': 0.8256
# Similarity between 'summary 432' and its 'predicted': 0.2767
# Similarity between 'summary 433' and its 'predicted': 0.7508
# Similarity between 'summary 434' and its 'predicted': 0.7318
# Similarity between 'summary 435' and its 'predicted': 0.8164
# Similarity between 'summary 436' and its 'predicted': 0.5610
# Similarity between 'summary 437' and its 'predicted': 0.8779
# Similarity between 'summary 438' and its 'predicted': 0.2629
# Similarity between 'summary 439' and its 'predicted': 0.7610
# Similarity between 'summary 440' and its 'predicted': 0.9373
# Similarity between 'summary 441' and its 'predicted': 0.7108
# Similarity between 'summary 442' and its 'predicted': 0.7163
# Similarity between 'summary 443' and its 'predicted': 0.3512
# Similarity between 'summary 444' and its 'predicted': 0.7064
# Similarity between 'summary 445' and its 'predicted': 0.5204
# Similarity between 'summary 446' and its 'predicted': 0.6126
# Similarity between 'summary 447' and its 'predicted': 0.3572
# Similarity between 'summary 448' and its 'predicted': 0.4269
# Similarity between 'summary 449' and its 'predicted': 0.3729
# Similarity between 'summary 450' and its 'predicted': 0.5293
# Similarity between 'summary 451' and its 'predicted': 0.5088
# Similarity between 'summary 452' and its 'predicted': 0.6613
# Similarity between 'summary 453' and its 'predicted': 0.6317
# Similarity between 'summary 454' and its 'predicted': 0.7857
# Similarity between 'summary 455' and its 'predicted': 0.6815
# Similarity between 'summary 456' and its 'predicted': 0.8109
# Similarity between 'summary 457' and its 'predicted': 0.8057
# Similarity between 'summary 458' and its 'predicted': 0.6397
# Similarity between 'summary 459' and its 'predicted': 0.2992
# Similarity between 'summary 460' and its 'predicted': 0.3671
# Similarity between 'summary 461' and its 'predicted': 0.4581
# Similarity between 'summary 462' and its 'predicted': 0.2362
# Similarity between 'summary 463' and its 'predicted': 0.3969
# Similarity between 'summary 464' and its 'predicted': 0.5956
# Similarity between 'summary 465' and its 'predicted': 0.8331
# Similarity between 'summary 466' and its 'predicted': 0.7960
# Similarity between 'summary 467' and its 'predicted': 0.7799
# Similarity between 'summary 468' and its 'predicted': 0.3714
# Similarity between 'summary 469' and its 'predicted': 0.6464
# Similarity between 'summary 470' and its 'predicted': 0.8294
# Similarity between 'summary 471' and its 'predicted': 0.7366
# Similarity between 'summary 472' and its 'predicted': 0.5209
# Similarity between 'summary 473' and its 'predicted': 0.5305
# Similarity between 'summary 474' and its 'predicted': 0.8232
# Similarity between 'summary 475' and its 'predicted': 0.5076
# Similarity between 'summary 476' and its 'predicted': 0.8926
# Similarity between 'summary 477' and its 'predicted': 0.5923
# Similarity between 'summary 478' and its 'predicted': 0.6566
# Similarity between 'summary 479' and its 'predicted': 0.8008
# Similarity between 'summary 480' and its 'predicted': 0.7940
# Similarity between 'summary 481' and its 'predicted': 0.5332
# Similarity between 'summary 482' and its 'predicted': 0.8194
# Similarity between 'summary 483' and its 'predicted': 0.4988
# Similarity between 'summary 484' and its 'predicted': 0.6533
# Similarity between 'summary 485' and its 'predicted': 0.7492
# Similarity between 'summary 486' and its 'predicted': 0.4209
# Similarity between 'summary 487' and its 'predicted': 0.7674
# Similarity between 'summary 488' and its 'predicted': 0.1834
# Similarity between 'summary 489' and its 'predicted': 0.3046
# Similarity between 'summary 490' and its 'predicted': 0.4402
# Similarity between 'summary 491' and its 'predicted': 0.5690
# Similarity between 'summary 492' and its 'predicted': 0.6578
# Similarity between 'summary 493' and its 'predicted': 0.8572
# Similarity between 'summary 494' and its 'predicted': 0.7149
# Similarity between 'summary 495' and its 'predicted': 0.3294
# Similarity between 'summary 496' and its 'predicted': 0.5047
# Similarity between 'summary 497' and its 'predicted': 0.5608
# Similarity between 'summary 498' and its 'predicted': 0.7218
# Similarity between 'summary 499' and its 'predicted': 0.6032
# Similarity between 'summary 500' and its 'predicted': 0.7393
# Similarity between 'summary 501' and its 'predicted': 0.8333
# Similarity between 'summary 502' and its 'predicted': 0.8435
# Similarity between 'summary 503' and its 'predicted': 0.4690
# Similarity between 'summary 504' and its 'predicted': 0.9111
# Similarity between 'summary 505' and its 'predicted': 0.3651
# Similarity between 'summary 506' and its 'predicted': 0.7784
# Similarity between 'summary 507' and its 'predicted': 0.6642
# Similarity between 'summary 508' and its 'predicted': 0.6405
# Similarity between 'summary 509' and its 'predicted': 0.5033
# Similarity between 'summary 510' and its 'predicted': 0.4752
# Similarity between 'summary 511' and its 'predicted': 0.7843
# Similarity between 'summary 512' and its 'predicted': 0.6969
# Similarity between 'summary 513' and its 'predicted': 0.7123
# Similarity between 'summary 514' and its 'predicted': 0.7595
# Similarity between 'summary 515' and its 'predicted': 0.4962
# Similarity between 'summary 516' and its 'predicted': 0.4691
# Similarity between 'summary 517' and its 'predicted': 0.3407
# Similarity between 'summary 518' and its 'predicted': 0.6608
# Similarity between 'summary 519' and its 'predicted': 0.4641
# Similarity between 'summary 520' and its 'predicted': 0.6706
# Similarity between 'summary 521' and its 'predicted': 0.5560
# Similarity between 'summary 522' and its 'predicted': 0.6826
# Similarity between 'summary 523' and its 'predicted': 0.6055
# Similarity between 'summary 524' and its 'predicted': 0.7933
# Similarity between 'summary 525' and its 'predicted': 0.5838
# Similarity between 'summary 526' and its 'predicted': 0.7015
# Similarity between 'summary 527' and its 'predicted': 0.5968
# Similarity between 'summary 528' and its 'predicted': 0.8098
# Similarity between 'summary 529' and its 'predicted': 0.5545
# Similarity between 'summary 530' and its 'predicted': 0.9104
# Similarity between 'summary 531' and its 'predicted': 0.9131
# Similarity between 'summary 532' and its 'predicted': 0.6833
# Similarity between 'summary 533' and its 'predicted': 0.8851
# Similarity between 'summary 534' and its 'predicted': 0.7103
# Similarity between 'summary 535' and its 'predicted': 0.7888
# Similarity between 'summary 536' and its 'predicted': 0.7979
# Similarity between 'summary 537' and its 'predicted': 0.7758
# Similarity between 'summary 538' and its 'predicted': 0.6911
# Similarity between 'summary 539' and its 'predicted': 0.4901
# Similarity between 'summary 540' and its 'predicted': 0.6810
# Similarity between 'summary 541' and its 'predicted': 0.5163
# Similarity between 'summary 542' and its 'predicted': 0.3837
# Similarity between 'summary 543' and its 'predicted': 0.5435
# Similarity between 'summary 544' and its 'predicted': 0.2806
# Similarity between 'summary 545' and its 'predicted': 0.5024
# Similarity between 'summary 546' and its 'predicted': 0.7832
# Similarity between 'summary 547' and its 'predicted': 0.6632
# Similarity between 'summary 548' and its 'predicted': 0.5971
# Similarity between 'summary 549' and its 'predicted': 0.5481
# Similarity between 'summary 550' and its 'predicted': 0.7233
# Similarity between 'summary 551' and its 'predicted': 0.6843
# Similarity between 'summary 552' and its 'predicted': 0.8196
# Similarity between 'summary 553' and its 'predicted': 0.4435
# Similarity between 'summary 554' and its 'predicted': 0.6834
# Similarity between 'summary 555' and its 'predicted': 0.8920
# Similarity between 'summary 556' and its 'predicted': 0.8973
# Similarity between 'summary 557' and its 'predicted': 0.7063
# Similarity between 'summary 558' and its 'predicted': 0.7558
# Similarity between 'summary 559' and its 'predicted': 0.7503
# Similarity between 'summary 560' and its 'predicted': 0.2121
# Similarity between 'summary 561' and its 'predicted': 0.6329
# Similarity between 'summary 562' and its 'predicted': 0.6964
# Similarity between 'summary 563' and its 'predicted': 0.6360
# Similarity between 'summary 564' and its 'predicted': 0.4162
# Similarity between 'summary 565' and its 'predicted': 0.7286
# Similarity between 'summary 566' and its 'predicted': 0.1986
# Similarity between 'summary 567' and its 'predicted': 0.7130
# Similarity between 'summary 568' and its 'predicted': 0.8391
# Similarity between 'summary 569' and its 'predicted': 0.5976
# Similarity between 'summary 570' and its 'predicted': 0.7207
# Similarity between 'summary 571' and its 'predicted': 0.6526
# Similarity between 'summary 572' and its 'predicted': 0.3940
# Similarity between 'summary 573' and its 'predicted': 0.5556
# Similarity between 'summary 574' and its 'predicted': 0.6654
# Similarity between 'summary 575' and its 'predicted': 0.8311
# Similarity between 'summary 576' and its 'predicted': 0.6699
# Similarity between 'summary 577' and its 'predicted': 0.8418
# Similarity between 'summary 578' and its 'predicted': 0.6123
# Similarity between 'summary 579' and its 'predicted': 0.6344
# Similarity between 'summary 580' and its 'predicted': 0.4024
# Similarity between 'summary 581' and its 'predicted': 0.5774
# Similarity between 'summary 582' and its 'predicted': 0.7335
# Similarity between 'summary 583' and its 'predicted': 0.6044
# Similarity between 'summary 584' and its 'predicted': 0.5930
# Similarity between 'summary 585' and its 'predicted': 0.8690
# Similarity between 'summary 586' and its 'predicted': 0.7496
# Similarity between 'summary 587' and its 'predicted': 0.8195
# Similarity between 'summary 588' and its 'predicted': 0.6188
# Similarity between 'summary 589' and its 'predicted': 0.5611
# Similarity between 'summary 590' and its 'predicted': 0.6786
# Similarity between 'summary 591' and its 'predicted': 0.6623
# Similarity between 'summary 592' and its 'predicted': 0.7457
# Similarity between 'summary 593' and its 'predicted': 0.7494
# Similarity between 'summary 594' and its 'predicted': 0.5471
# Similarity between 'summary 595' and its 'predicted': 0.3736
# Similarity between 'summary 596' and its 'predicted': 0.5037
# Similarity between 'summary 597' and its 'predicted': 0.6536
# Similarity between 'summary 598' and its 'predicted': 0.5064
# Similarity between 'summary 599' and its 'predicted': 0.8485
# Similarity between 'summary 600' and its 'predicted': 0.5713
# Similarity between 'summary 601' and its 'predicted': 0.7293
# Similarity between 'summary 602' and its 'predicted': 0.7167
# Similarity between 'summary 603' and its 'predicted': 0.7974
# Similarity between 'summary 604' and its 'predicted': 0.9354
# Similarity between 'summary 605' and its 'predicted': 0.7080
# Similarity between 'summary 606' and its 'predicted': 0.1301
# Similarity between 'summary 607' and its 'predicted': 0.4685
# Similarity between 'summary 608' and its 'predicted': 0.2736
# Similarity between 'summary 609' and its 'predicted': 0.0122
# Similarity between 'summary 610' and its 'predicted': 0.8580
# Similarity between 'summary 611' and its 'predicted': 0.8191
# Similarity between 'summary 612' and its 'predicted': 0.1166
# Similarity between 'summary 613' and its 'predicted': 0.6830
# Similarity between 'summary 614' and its 'predicted': 0.6877
# Similarity between 'summary 615' and its 'predicted': 0.7218
# Similarity between 'summary 616' and its 'predicted': 0.8527
# Similarity between 'summary 617' and its 'predicted': 0.7022
# Similarity between 'summary 618' and its 'predicted': 0.6380
# Similarity between 'summary 619' and its 'predicted': -0.0077
# Similarity between 'summary 620' and its 'predicted': 0.5035
# Similarity between 'summary 621' and its 'predicted': 0.8451
# Similarity between 'summary 622' and its 'predicted': 0.7600
# Similarity between 'summary 623' and its 'predicted': 0.8760
# Similarity between 'summary 624' and its 'predicted': 0.5065
# Similarity between 'summary 625' and its 'predicted': 0.6612
# Similarity between 'summary 626' and its 'predicted': 0.3313
# Similarity between 'summary 627' and its 'predicted': 0.8508
# Similarity between 'summary 628' and its 'predicted': 0.7118
# Similarity between 'summary 629' and its 'predicted': 0.8099
# Similarity between 'summary 630' and its 'predicted': 0.7641
# Similarity between 'summary 631' and its 'predicted': 0.6637
# Similarity between 'summary 632' and its 'predicted': 0.8007
# Similarity between 'summary 633' and its 'predicted': 0.7586
# Similarity between 'summary 634' and its 'predicted': 0.8693
# Similarity between 'summary 635' and its 'predicted': 0.2371
# Similarity between 'summary 636' and its 'predicted': 0.6881
# Similarity between 'summary 637' and its 'predicted': 0.7141
# Similarity between 'summary 638' and its 'predicted': 0.7898
# Similarity between 'summary 639' and its 'predicted': 0.7765
# Similarity between 'summary 640' and its 'predicted': 0.8408
# Similarity between 'summary 641' and its 'predicted': 0.6273
# Similarity between 'summary 642' and its 'predicted': 0.6688
# Similarity between 'summary 643' and its 'predicted': 0.7106
# Similarity between 'summary 644' and its 'predicted': 0.7944
# Similarity between 'summary 645' and its 'predicted': 0.5657
# Similarity between 'summary 646' and its 'predicted': 0.6433
# Similarity between 'summary 647' and its 'predicted': 0.7817
# Similarity between 'summary 648' and its 'predicted': 0.7093
# Similarity between 'summary 649' and its 'predicted': 0.5533
# Similarity between 'summary 650' and its 'predicted': 0.4251
# Similarity between 'summary 651' and its 'predicted': 0.5828
# Similarity between 'summary 652' and its 'predicted': 0.7168
# Similarity between 'summary 653' and its 'predicted': 0.8786
# Similarity between 'summary 654' and its 'predicted': 0.6644
# Similarity between 'summary 655' and its 'predicted': 0.8814
# Similarity between 'summary 656' and its 'predicted': 0.2674
# Similarity between 'summary 657' and its 'predicted': 0.8165
# Similarity between 'summary 658' and its 'predicted': 0.5234
# Similarity between 'summary 659' and its 'predicted': 0.8363
# Similarity between 'summary 660' and its 'predicted': 0.7128
# Similarity between 'summary 661' and its 'predicted': 0.5879
# Similarity between 'summary 662' and its 'predicted': 0.6646
# Similarity between 'summary 663' and its 'predicted': 0.5265
# Similarity between 'summary 664' and its 'predicted': 0.8120
# Similarity between 'summary 665' and its 'predicted': 0.8476
# Similarity between 'summary 666' and its 'predicted': 0.7104
# Similarity between 'summary 667' and its 'predicted': 0.1864
# Similarity between 'summary 668' and its 'predicted': 0.6792
# Similarity between 'summary 669' and its 'predicted': 0.4628
# Similarity between 'summary 670' and its 'predicted': 0.8433
# Similarity between 'summary 671' and its 'predicted': 0.7240
# Similarity between 'summary 672' and its 'predicted': 0.9097
# Similarity between 'summary 673' and its 'predicted': -0.0948
# Similarity between 'summary 674' and its 'predicted': 0.7626
# Similarity between 'summary 675' and its 'predicted': 0.8205
# Similarity between 'summary 676' and its 'predicted': 0.4912
# Similarity between 'summary 677' and its 'predicted': 0.5821
# Similarity between 'summary 678' and its 'predicted': 0.7438
# Similarity between 'summary 679' and its 'predicted': 0.7764
# Similarity between 'summary 680' and its 'predicted': 0.6263
# Similarity between 'summary 681' and its 'predicted': 0.1436
# Similarity between 'summary 682' and its 'predicted': 0.7366
# Similarity between 'summary 683' and its 'predicted': 0.6666
# Similarity between 'summary 684' and its 'predicted': 0.2951
# Similarity between 'summary 685' and its 'predicted': 0.5696
# Similarity between 'summary 686' and its 'predicted': 0.6981
# Similarity between 'summary 687' and its 'predicted': 0.5150
# Similarity between 'summary 688' and its 'predicted': 0.4132
# Similarity between 'summary 689' and its 'predicted': 0.6885
# Similarity between 'summary 690' and its 'predicted': 0.6131
# Similarity between 'summary 691' and its 'predicted': 0.6391
# Similarity between 'summary 692' and its 'predicted': 0.6981
# Similarity between 'summary 693' and its 'predicted': 0.9364
# Similarity between 'summary 694' and its 'predicted': 0.8140
# Similarity between 'summary 695' and its 'predicted': 0.6448
# Similarity between 'summary 696' and its 'predicted': 0.7848
# Similarity between 'summary 697' and its 'predicted': 0.7758
# Similarity between 'summary 698' and its 'predicted': 0.6671
# Similarity between 'summary 699' and its 'predicted': 0.8592
# Similarity between 'summary 700' and its 'predicted': 0.0148
# Similarity between 'summary 701' and its 'predicted': 0.6391
# Similarity between 'summary 702' and its 'predicted': 0.6294
# Similarity between 'summary 703' and its 'predicted': 0.7532
# Similarity between 'summary 704' and its 'predicted': 0.6375
# Similarity between 'summary 705' and its 'predicted': 0.6693
# Similarity between 'summary 706' and its 'predicted': 0.4035
# Similarity between 'summary 707' and its 'predicted': 0.8428
# Similarity between 'summary 708' and its 'predicted': 0.8159
# Similarity between 'summary 709' and its 'predicted': 0.6452
# Similarity between 'summary 710' and its 'predicted': 0.5413
# Similarity between 'summary 711' and its 'predicted': 0.6723
# Similarity between 'summary 712' and its 'predicted': 0.6055
# Similarity between 'summary 713' and its 'predicted': 0.6852
# Similarity between 'summary 714' and its 'predicted': 0.8265
# Similarity between 'summary 715' and its 'predicted': 0.5249
# Similarity between 'summary 716' and its 'predicted': 0.7551
# Similarity between 'summary 717' and its 'predicted': 0.8502
# Similarity between 'summary 718' and its 'predicted': 0.7488
# Similarity between 'summary 719' and its 'predicted': 0.6249
# Similarity between 'summary 720' and its 'predicted': 0.8003
# Similarity between 'summary 721' and its 'predicted': 0.3459
# Similarity between 'summary 722' and its 'predicted': 0.5932
# Similarity between 'summary 723' and its 'predicted': 0.4446
# Similarity between 'summary 724' and its 'predicted': 0.7593
# Similarity between 'summary 725' and its 'predicted': 0.7725
# Similarity between 'summary 726' and its 'predicted': 0.7038
# Similarity between 'summary 727' and its 'predicted': 0.7607
# Similarity between 'summary 728' and its 'predicted': 0.6920
# Similarity between 'summary 729' and its 'predicted': 0.5246
# Similarity between 'summary 730' and its 'predicted': 0.7821
# Similarity between 'summary 731' and its 'predicted': 0.8625
# Similarity between 'summary 732' and its 'predicted': 0.5873
# Similarity between 'summary 733' and its 'predicted': 0.6151
# Similarity between 'summary 734' and its 'predicted': 0.6864
# Similarity between 'summary 735' and its 'predicted': 0.6304
# Similarity between 'summary 736' and its 'predicted': 0.6804
# Similarity between 'summary 737' and its 'predicted': 0.6247
# Similarity between 'summary 738' and its 'predicted': 0.3344
# Similarity between 'summary 739' and its 'predicted': 0.8157
# Similarity between 'summary 740' and its 'predicted': -0.0149
# Similarity between 'summary 741' and its 'predicted': 0.3982
# Similarity between 'summary 742' and its 'predicted': 0.8464
# Similarity between 'summary 743' and its 'predicted': 0.6934
# Similarity between 'summary 744' and its 'predicted': 0.4274
# Similarity between 'summary 745' and its 'predicted': 0.6310
# Similarity between 'summary 746' and its 'predicted': 0.7508
# Similarity between 'summary 747' and its 'predicted': 0.7880
# Similarity between 'summary 748' and its 'predicted': 0.6318
# Similarity between 'summary 749' and its 'predicted': 0.6638
# Similarity between 'summary 750' and its 'predicted': 0.7975
# Similarity between 'summary 751' and its 'predicted': 0.7620
# Similarity between 'summary 752' and its 'predicted': 0.8597
# Similarity between 'summary 753' and its 'predicted': 0.8027
# Similarity between 'summary 754' and its 'predicted': 0.8486
# Similarity between 'summary 755' and its 'predicted': 0.2753
# Similarity between 'summary 756' and its 'predicted': 0.9713
# Similarity between 'summary 757' and its 'predicted': 0.7616
# Similarity between 'summary 758' and its 'predicted': 0.8712
# Similarity between 'summary 759' and its 'predicted': 0.2444
# Similarity between 'summary 760' and its 'predicted': 0.8206
# Similarity between 'summary 761' and its 'predicted': 0.8254
# Similarity between 'summary 762' and its 'predicted': 0.6794
# Similarity between 'summary 763' and its 'predicted': 0.5688
# Similarity between 'summary 764' and its 'predicted': 0.7963
# Similarity between 'summary 765' and its 'predicted': 0.6769
# Similarity between 'summary 766' and its 'predicted': 0.6863
# Similarity between 'summary 767' and its 'predicted': 0.7165
# Similarity between 'summary 768' and its 'predicted': 0.8736
# Similarity between 'summary 769' and its 'predicted': 0.6838
# Similarity between 'summary 770' and its 'predicted': 0.4670
# Similarity between 'summary 771' and its 'predicted': 0.7010
# Similarity between 'summary 772' and its 'predicted': 0.7442
# Similarity between 'summary 773' and its 'predicted': 0.6190
# Similarity between 'summary 774' and its 'predicted': 0.6471
# Similarity between 'summary 775' and its 'predicted': 0.6966
# Similarity between 'summary 776' and its 'predicted': 0.4914
# Similarity between 'summary 777' and its 'predicted': 0.8732
# Similarity between 'summary 778' and its 'predicted': 0.1849
# Similarity between 'summary 779' and its 'predicted': 0.3984
# Similarity between 'summary 780' and its 'predicted': 0.7056
# Similarity between 'summary 781' and its 'predicted': 0.3569
# Similarity between 'summary 782' and its 'predicted': 0.8278
# Similarity between 'summary 783' and its 'predicted': 0.8435
# Similarity between 'summary 784' and its 'predicted': 0.2736
# Similarity between 'summary 785' and its 'predicted': 0.5640
# Similarity between 'summary 786' and its 'predicted': 0.6222
# Similarity between 'summary 787' and its 'predicted': 0.6460
# Similarity between 'summary 788' and its 'predicted': 0.9185
# ...
# Similarity between 'summary 1743' and its 'predicted': 0.7851
# Similarity between 'summary 1744' and its 'predicted': 0.6037
# Similarity between 'summary 1745' and its 'predicted': 0.6224
# Similarity between 'summary 1746' and its 'predicted': 0.7749
# Similarity between 'summary 1747' and its 'predicted': 0.7835
# Similarity between 'summary 1748' and its 'predicted': 0.8786
# Similarity between 'summary 1749' and its 'predicted': 0.7904
# Similarity between 'summary 1750' and its 'predicted': 0.5827
# Similarity between 'summary 1751' and its 'predicted': 0.7679
# Similarity between 'summary 1752' and its 'predicted': 0.4788
# Similarity between 'summary 1753' and its 'predicted': 0.5562
# Similarity between 'summary 1754' and its 'predicted': 0.8077
# Similarity between 'summary 1755' and its 'predicted': 0.6131
# Similarity between 'summary 1756' and its 'predicted': 0.6633
# Similarity between 'summary 1757' and its 'predicted': 0.7385
# Similarity between 'summary 1758' and its 'predicted': 0.3766
# Similarity between 'summary 1759' and its 'predicted': 0.4260
# Similarity between 'summary 1760' and its 'predicted': 0.5398
# Similarity between 'summary 1761' and its 'predicted': 0.8776
# Similarity between 'summary 1762' and its 'predicted': -0.0279
# Similarity between 'summary 1763' and its 'predicted': 0.8515
# Similarity between 'summary 1764' and its 'predicted': 0.6793
# Similarity between 'summary 1765' and its 'predicted': 0.6722
# Similarity between 'summary 1766' and its 'predicted': 0.8877
# Similarity between 'summary 1767' and its 'predicted': 0.5002
# Similarity between 'summary 1768' and its 'predicted': 0.7098
# Similarity between 'summary 1769' and its 'predicted': 0.5004
# Similarity between 'summary 1770' and its 'predicted': 0.8472
# Similarity between 'summary 1771' and its 'predicted': 0.6445
# Similarity between 'summary 1772' and its 'predicted': 0.8304
# Similarity between 'summary 1773' and its 'predicted': 0.6851
# Similarity between 'summary 1774' and its 'predicted': 0.6412
# Similarity between 'summary 1775' and its 'predicted': 0.5836
# Similarity between 'summary 1776' and its 'predicted': 0.7165
# Similarity between 'summary 1777' and its 'predicted': 0.8543
# Similarity between 'summary 1778' and its 'predicted': 0.8718
# Similarity between 'summary 1779' and its 'predicted': 0.4559
# Similarity between 'summary 1780' and its 'predicted': 0.6949
# Similarity between 'summary 1781' and its 'predicted': 0.6749
# Similarity between 'summary 1782' and its 'predicted': 0.6953
# Similarity between 'summary 1783' and its 'predicted': 0.7830
# Similarity between 'summary 1784' and its 'predicted': 0.8814
# Similarity between 'summary 1785' and its 'predicted': 0.7361
# Similarity between 'summary 1786' and its 'predicted': 0.7244
# Similarity between 'summary 1787' and its 'predicted': 0.7804
# Similarity between 'summary 1788' and its 'predicted': 0.4827
# Similarity between 'summary 1789' and its 'predicted': 0.0393
# Similarity between 'summary 1790' and its 'predicted': 0.4745
# Similarity between 'summary 1791' and its 'predicted': 0.6507
# Similarity between 'summary 1792' and its 'predicted': 0.7681
# Similarity between 'summary 1793' and its 'predicted': 0.4520
# Similarity between 'summary 1794' and its 'predicted': 0.8069
# Similarity between 'summary 1795' and its 'predicted': 0.6995
# Similarity between 'summary 1796' and its 'predicted': 0.6638
# Similarity between 'summary 1797' and its 'predicted': 0.6149
# Similarity between 'summary 1798' and its 'predicted': 0.7992
# Similarity between 'summary 1799' and its 'predicted': 0.8644
# Similarity between 'summary 1800' and its 'predicted': 0.8519
# Similarity between 'summary 1801' and its 'predicted': 0.8148
# Similarity between 'summary 1802' and its 'predicted': 0.5079
# Similarity between 'summary 1803' and its 'predicted': 0.7423
# Similarity between 'summary 1804' and its 'predicted': 0.5329
# Similarity between 'summary 1805' and its 'predicted': 0.7582
# Similarity between 'summary 1806' and its 'predicted': 0.5131
# Similarity between 'summary 1807' and its 'predicted': 0.8711
# Similarity between 'summary 1808' and its 'predicted': 0.4958
# Similarity between 'summary 1809' and its 'predicted': 0.7785
# Similarity between 'summary 1810' and its 'predicted': 0.6596
# Similarity between 'summary 1811' and its 'predicted': 0.0664
# Similarity between 'summary 1812' and its 'predicted': 0.8199
# Similarity between 'summary 1813' and its 'predicted': 0.2872
# Similarity between 'summary 1814' and its 'predicted': 0.8864
# Similarity between 'summary 1815' and its 'predicted': 0.7607
# Similarity between 'summary 1816' and its 'predicted': 0.6862
# Similarity between 'summary 1817' and its 'predicted': 0.3226
# Similarity between 'summary 1818' and its 'predicted': 0.5610
# Similarity between 'summary 1819' and its 'predicted': 0.8157
# Similarity between 'summary 1820' and its 'predicted': 0.6544
# Similarity between 'summary 1821' and its 'predicted': 0.1398
# Similarity between 'summary 1822' and its 'predicted': 0.7205
# Similarity between 'summary 1823' and its 'predicted': 0.6348
# Similarity between 'summary 1824' and its 'predicted': 0.1231
# Similarity between 'summary 1825' and its 'predicted': 0.7894
# Similarity between 'summary 1826' and its 'predicted': 0.6246
# Similarity between 'summary 1827' and its 'predicted': 0.9105
# Similarity between 'summary 1828' and its 'predicted': 0.7158
# Similarity between 'summary 1829' and its 'predicted': 0.7994
# Similarity between 'summary 1830' and its 'predicted': 0.6857
# Similarity between 'summary 1831' and its 'predicted': 0.8751
# Similarity between 'summary 1832' and its 'predicted': 0.8648
# Similarity between 'summary 1833' and its 'predicted': 0.5950
# Similarity between 'summary 1834' and its 'predicted': 0.8116
# Similarity between 'summary 1835' and its 'predicted': 0.6743
# Similarity between 'summary 1836' and its 'predicted': 0.1060
# Similarity between 'summary 1837' and its 'predicted': 0.5429
# Similarity between 'summary 1838' and its 'predicted': 0.1241
# Similarity between 'summary 1839' and its 'predicted': 0.4562
# Similarity between 'summary 1840' and its 'predicted': 0.1204
# Similarity between 'summary 1841' and its 'predicted': 0.6140
# Similarity between 'summary 1842' and its 'predicted': 0.6642
# Similarity between 'summary 1843' and its 'predicted': 0.5999
# Similarity between 'summary 1844' and its 'predicted': 0.9180
# Similarity between 'summary 1845' and its 'predicted': 0.5415
# Similarity between 'summary 1846' and its 'predicted': 0.7968
# Similarity between 'summary 1847' and its 'predicted': 0.7680
# Similarity between 'summary 1848' and its 'predicted': 0.7436
# Similarity between 'summary 1849' and its 'predicted': 0.6817
# Similarity between 'summary 1850' and its 'predicted': 0.6768
# Similarity between 'summary 1851' and its 'predicted': 0.8434
# Similarity between 'summary 1852' and its 'predicted': 0.5484
# Similarity between 'summary 1853' and its 'predicted': 0.4925
# Similarity between 'summary 1854' and its 'predicted': 0.8483
# Similarity between 'summary 1855' and its 'predicted': 0.7788
# Similarity between 'summary 1856' and its 'predicted': 0.6618
# Similarity between 'summary 1857' and its 'predicted': 0.6660
# Similarity between 'summary 1858' and its 'predicted': 0.8247
# Similarity between 'summary 1859' and its 'predicted': 0.2892
# Similarity between 'summary 1860' and its 'predicted': 0.8642
# Similarity between 'summary 1861' and its 'predicted': 0.7590
# Similarity between 'summary 1862' and its 'predicted': 0.1711
# Similarity between 'summary 1863' and its 'predicted': 0.7038
# Similarity between 'summary 1864' and its 'predicted': 0.8810
# Similarity between 'summary 1865' and its 'predicted': 0.7463
# Similarity between 'summary 1866' and its 'predicted': 0.8281
# Similarity between 'summary 1867' and its 'predicted': 0.6656
# Similarity between 'summary 1868' and its 'predicted': 0.4622
# Similarity between 'summary 1869' and its 'predicted': 0.6347
# Similarity between 'summary 1870' and its 'predicted': 0.8536
# Similarity between 'summary 1871' and its 'predicted': 0.8014
# Similarity between 'summary 1872' and its 'predicted': 0.6450
# Similarity between 'summary 1873' and its 'predicted': 0.7097
# Similarity between 'summary 1874' and its 'predicted': 0.6557
# Similarity between 'summary 1875' and its 'predicted': 0.2903
# Similarity between 'summary 1876' and its 'predicted': 0.7945
# Similarity between 'summary 1877' and its 'predicted': 0.5500
# Similarity between 'summary 1878' and its 'predicted': 0.6691
# Similarity between 'summary 1879' and its 'predicted': 0.8325
# Similarity between 'summary 1880' and its 'predicted': 0.8591
# Similarity between 'summary 1881' and its 'predicted': 0.7641
# Similarity between 'summary 1882' and its 'predicted': 0.6831
# Similarity between 'summary 1883' and its 'predicted': 0.0636
# Similarity between 'summary 1884' and its 'predicted': 0.8731
# Similarity between 'summary 1885' and its 'predicted': 0.7967
# Similarity between 'summary 1886' and its 'predicted': 0.8825
# Similarity between 'summary 1887' and its 'predicted': 0.8968
# Similarity between 'summary 1888' and its 'predicted': 0.1763
# Similarity between 'summary 1889' and its 'predicted': 0.2131
# Similarity between 'summary 1890' and its 'predicted': 0.9268
# Similarity between 'summary 1891' and its 'predicted': 0.1037
# Similarity between 'summary 1892' and its 'predicted': 0.5591
# Similarity between 'summary 1893' and its 'predicted': 0.7609
# Similarity between 'summary 1894' and its 'predicted': 0.3987
# Similarity between 'summary 1895' and its 'predicted': 0.6301
# Similarity between 'summary 1896' and its 'predicted': 0.4347
# Similarity between 'summary 1897' and its 'predicted': 0.5628
# Similarity between 'summary 1898' and its 'predicted': 0.6274
# Similarity between 'summary 1899' and its 'predicted': 0.4559
# Similarity between 'summary 1900' and its 'predicted': 0.7461
# Similarity between 'summary 1901' and its 'predicted': 0.7439
# Similarity between 'summary 1902' and its 'predicted': 0.7574
# Similarity between 'summary 1903' and its 'predicted': 0.3789
# Similarity between 'summary 1904' and its 'predicted': 0.6655
# Similarity between 'summary 1905' and its 'predicted': 0.8746
# Similarity between 'summary 1906' and its 'predicted': 0.5448
# Similarity between 'summary 1907' and its 'predicted': 0.8753
# Similarity between 'summary 1908' and its 'predicted': 0.6205
# Similarity between 'summary 1909' and its 'predicted': 0.5642
# Similarity between 'summary 1910' and its 'predicted': 0.7051
# Similarity between 'summary 1911' and its 'predicted': 0.7198
# Similarity between 'summary 1912' and its 'predicted': 0.6954
# Similarity between 'summary 1913' and its 'predicted': 0.4356
# Similarity between 'summary 1914' and its 'predicted': 0.7303
# Similarity between 'summary 1915' and its 'predicted': 0.3522
# Similarity between 'summary 1916' and its 'predicted': 0.3246
# Similarity between 'summary 1917' and its 'predicted': 0.6772
# Similarity between 'summary 1918' and its 'predicted': 0.6110
# Similarity between 'summary 1919' and its 'predicted': 0.7002
# Similarity between 'summary 1920' and its 'predicted': 0.8571
# Similarity between 'summary 1921' and its 'predicted': 0.8252
# Similarity between 'summary 1922' and its 'predicted': 0.6854
# Similarity between 'summary 1923' and its 'predicted': 0.5839
# Similarity between 'summary 1924' and its 'predicted': 0.7157
# Similarity between 'summary 1925' and its 'predicted': 0.5653
# Similarity between 'summary 1926' and its 'predicted': 0.3786
# Similarity between 'summary 1927' and its 'predicted': 0.3563
# Similarity between 'summary 1928' and its 'predicted': 0.5088
# Similarity between 'summary 1929' and its 'predicted': 0.8238
# Similarity between 'summary 1930' and its 'predicted': 0.5743
# Similarity between 'summary 1931' and its 'predicted': 0.4191
# Similarity between 'summary 1932' and its 'predicted': 0.6426
# Similarity between 'summary 1933' and its 'predicted': 0.7891
# Similarity between 'summary 1934' and its 'predicted': 0.7452
# Similarity between 'summary 1935' and its 'predicted': 0.6637
# Similarity between 'summary 1936' and its 'predicted': 0.6780
# Similarity between 'summary 1937' and its 'predicted': 0.6217
# Similarity between 'summary 1938' and its 'predicted': 0.7469
# Similarity between 'summary 1939' and its 'predicted': 0.8883
# Similarity between 'summary 1940' and its 'predicted': 0.7649
# Similarity between 'summary 1941' and its 'predicted': 0.6688
# Similarity between 'summary 1942' and its 'predicted': 0.7895
# Similarity between 'summary 1943' and its 'predicted': 0.6658
# Similarity between 'summary 1944' and its 'predicted': 0.2647
# Similarity between 'summary 1945' and its 'predicted': 0.9406
# Similarity between 'summary 1946' and its 'predicted': 0.7711
# Similarity between 'summary 1947' and its 'predicted': 0.6240
# Similarity between 'summary 1948' and its 'predicted': 0.3557
# Similarity between 'summary 1949' and its 'predicted': 0.5449
# Similarity between 'summary 1950' and its 'predicted': 0.6865
# Similarity between 'summary 1951' and its 'predicted': 0.6893
# Similarity between 'summary 1952' and its 'predicted': 0.0700
# Similarity between 'summary 1953' and its 'predicted': 0.7506
# Similarity between 'summary 1954' and its 'predicted': 0.6534
# Similarity between 'summary 1955' and its 'predicted': 0.6741
# Similarity between 'summary 1956' and its 'predicted': 0.6251
# Similarity between 'summary 1957' and its 'predicted': 0.7869
# Similarity between 'summary 1958' and its 'predicted': 0.8457
# Similarity between 'summary 1959' and its 'predicted': 0.8168
# Similarity between 'summary 1960' and its 'predicted': 0.7183
# Similarity between 'summary 1961' and its 'predicted': 0.9140
# Similarity between 'summary 1962' and its 'predicted': 0.6642
# Similarity between 'summary 1963' and its 'predicted': 0.2650
# Similarity between 'summary 1964' and its 'predicted': 0.6548
# Similarity between 'summary 1965' and its 'predicted': 0.5460
# Similarity between 'summary 1966' and its 'predicted': 0.5877
# Similarity between 'summary 1967' and its 'predicted': 0.8376
# Similarity between 'summary 1968' and its 'predicted': 0.7092
# Similarity between 'summary 1969' and its 'predicted': 0.3649
# Similarity between 'summary 1970' and its 'predicted': 0.7668
# Similarity between 'summary 1971' and its 'predicted': 0.7456
# Similarity between 'summary 1972' and its 'predicted': 0.0514
# Similarity between 'summary 1973' and its 'predicted': -0.0719
# Similarity between 'summary 1974' and its 'predicted': 0.7530
# Similarity between 'summary 1975' and its 'predicted': 0.5375
# Similarity between 'summary 1976' and its 'predicted': 0.8126
# Similarity between 'summary 1977' and its 'predicted': 0.7443
# Similarity between 'summary 1978' and its 'predicted': 0.6935
# Similarity between 'summary 1979' and its 'predicted': 0.7979
# Similarity between 'summary 1980' and its 'predicted': 0.6689
# Similarity between 'summary 1981' and its 'predicted': 0.3456
# Similarity between 'summary 1982' and its 'predicted': 0.8774
# Similarity between 'summary 1983' and its 'predicted': 0.8471
# Similarity between 'summary 1984' and its 'predicted': 0.7831
# Similarity between 'summary 1985' and its 'predicted': 0.7652
# Similarity between 'summary 1986' and its 'predicted': 0.5667
# Similarity between 'summary 1987' and its 'predicted': 0.4184
# Similarity between 'summary 1988' and its 'predicted': 0.7893
# Similarity between 'summary 1989' and its 'predicted': 0.3380
# Similarity between 'summary 1990' and its 'predicted': 0.7137
# Similarity between 'summary 1991' and its 'predicted': 0.2122
# Similarity between 'summary 1992' and its 'predicted': 0.6987
# Similarity between 'summary 1993' and its 'predicted': 0.3892
# Similarity between 'summary 1994' and its 'predicted': 0.8388
# Similarity between 'summary 1995' and its 'predicted': 0.7147
# Similarity between 'summary 1996' and its 'predicted': 0.3367
# Similarity between 'summary 1997' and its 'predicted': 0.5488
# Similarity between 'summary 1998' and its 'predicted': 0.6845
# Similarity between 'summary 1999' and its 'predicted': 0.7300
# Similarity between 'summary 2000' and its 'predicted': 0.5645

# %%
average_similarity = np.mean(similarity_scores)

#average similarity score
print(f'Average Cosine Similarity Score: {average_similarity:.4f}')
# Out:
# Average Cosine Similarity Score: 0.6496

# %%
plt.figure(figsize=(10, 6))
plt.bar(range(len(similarity_scores)), similarity_scores)
plt.xlabel('Sample Index')
plt.ylabel('Similarity Score')
plt.title('Cosin Similarity Scores between Original and Predicted Summaries')
plt.show()
